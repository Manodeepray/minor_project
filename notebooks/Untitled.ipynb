# %%
# !source notebook_venv/bin/activate

# %%
# !notebook_venv/bin/pip install deepface
# Out:
# ...
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 2.3 MB/s eta 0:00:00
# ...
#   Using cached pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
# ...
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# ...
#   Using cached pillow-11.1.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (9.1 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 3.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached jinja2-3.1.5-py3-none-any.whl.metadata (2.6 kB)
# ...
#   Using cached packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.7/47.7 kB 3.1 MB/s eta 0:00:00
# ...
#   Using cached ml_dtypes-0.5.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (21 kB)
# ...

# %%
cd ..

# %%
from deepface import DeepFace





if __name__ == "__main__":
    # verification = DeepFace.verify(img1_path = "yolo_dataset/train/manodeep/face_1.jpg",
    #                                img2_path = "yolo_dataset/train/manodeep/Screenshot 2025-01-01 195947.png_face_1.jpg",
    #                                model_name = "OpenFace")
    # print(f"Verification : {verification}")
    
    dfs = DeepFace.find(
    img_path = "faces/45_face_1.jpg",
    db_path = "yolo_dataset/train", 
    model_name = "OpenFace",
    )
    print(dfs)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 from deepface import DeepFace
#       7 if __name__ == "__main__":
#       8     # verification = DeepFace.verify(img1_path = "yolo_dataset/train/manodeep/face_1.jpg",
#       9     #                                img2_path = "yolo_dataset/train/manodeep/Screenshot 2025-01-01 195947.png_face_1.jpg",
#      10     #                                model_name = "OpenFace")
#      11     # print(f"Verification : {verification}")
#      13     dfs = DeepFace.find(
#      14     img_path = "faces/45_face_1.jpg",
#      15     db_path = "yolo_dataset/train",
#      16     model_name = "OpenFace",
#      17     )
#
# ModuleNotFoundError: No module named 'deepface'

# %%
# Out:
# zsh:1: command not found: ifconfig
